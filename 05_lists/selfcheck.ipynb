# %% [markdown]
# # Module 05 — self-check
#
# Set to `True` what you can do **right now, without looking it up**, then run the
# second cell. It tells you whether this module has anything for you.
#
# Nothing is recorded and nothing is graded. An honest `False` here saves more time
# than an optimistic `True`.

# %%
can = {
    "say what `b = a` does when `a` is a list, and how that differs from `a` being an int": False,
    "explain why `lst += [3]` is visible through an alias but `t += (3,)` is not": False,
    "take the last three items of a list and reverse it, without writing a loop": False,
    "copy a list of lists so that changing the copy leaves the original alone": False,
    "say what `x.sort()` returns, and when you would write `sorted(x)` instead": False,
    "write a list comprehension with a condition, and say when a loop reads better": False,
}

# %%
open = [q for q, yes in can.items() if not yes]

print(f"{len(can) - len(open)} of {len(can)}\n")

if not open:
    print("Skip this module. Skim explore.ipynb if you want to confirm the details.")
elif len(open) <= 2:
    print("Mostly there. Read explore.ipynb, then do the exercises for these two:\n")
else:
    print("Worth working through. These are what the module is for:\n")

for q in open:
    print(" -", q)

# %% [markdown]
# ---
#
# This is a filter, not a test. If most of it is `True`, read `explore.ipynb` for
# the two or three items that were not and go on to the next module.
